# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("/Users/bristi/Desktop/Preprocessing/southwest_train.csv")

# %% [markdown]
# #### Training Set

# %%
df_notcancelled = df[df["Cancelled"] == False]

# %%
df_notcancelled = df_notcancelled.drop('Cancelled', axis = 1)

# %%
df_train = df_notcancelled[df_notcancelled["Diverted"] == False]
df_train = df_train.drop('Diverted', axis = 1)

# %%
null_dep_time_count = df_train["DepTime"].isnull().sum()
print("Number of records with null DepTime:", null_dep_time_count)
# Out:
# Number of records with null DepTime: 0

# %%
df_train = df_train.drop("Airline", axis=1)

# %%
df_train.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 1  2018-01-09    LAS  OAK         925   1029.0             64.0      64.0
# 2  2018-01-09    LAS  OAK        1820   1826.0              6.0       6.0
# 4  2018-01-09    LAS  OAK        2155   2317.0             82.0      82.0
# 6  2018-01-09    LAS  OAK        1145   1436.0            171.0     171.0
# 8  2018-01-09    LAS  OAK         615    610.0              0.0      -5.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  WheelsOff  WheelsOn  TaxiIn  \
# 1   1154.0             54.0     64.0  ...     1045.0    1149.0     5.0
# 2   1949.0              0.0     67.0  ...     1838.0    1945.0     4.0
# 4     41.0             76.0     71.0  ...     2325.0      36.0     5.0
# 6   1607.0            167.0     64.0  ...     1458.0    1602.0     5.0
# 8    733.0              0.0     62.0  ...      625.0     727.0     6.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# ...

# %%
enc_nom_1 = (df_train.groupby('Origin').size()) / len(df_train)
enc_nom_1
# Out:
# Origin
# ABQ    0.007592
# ALB    0.002804
# AMA    0.001254
# ATL    0.029845
# AUS    0.017642
#          ...
# SYR    0.000031
# TPA    0.020712
# TUL    0.003358
# TUS    0.002983
# VPS    0.000307
# Length: 109, dtype: float64

# %%
df_train['Origin_enc'] = df_train['Origin'].apply(lambda x : enc_nom_1[x])
df_train.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 1  2018-01-09    LAS  OAK         925   1029.0             64.0      64.0
# 2  2018-01-09    LAS  OAK        1820   1826.0              6.0       6.0
# 4  2018-01-09    LAS  OAK        2155   2317.0             82.0      82.0
# 6  2018-01-09    LAS  OAK        1145   1436.0            171.0     171.0
# 8  2018-01-09    LAS  OAK         615    610.0              0.0      -5.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  WheelsOn  TaxiIn  CRSArrTime  \
# 1   1154.0             54.0     64.0  ...    1149.0     5.0        1100
# 2   1949.0              0.0     67.0  ...    1945.0     4.0        1955
# 4     41.0             76.0     71.0  ...      36.0     5.0        2325
# 6   1607.0            167.0     64.0  ...    1602.0     5.0        1320
# 8    733.0              0.0     62.0  ...     727.0     6.0         750
#
#    ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  DistanceGroup  \
# ...

# %%
enc_nom_2 = (df_train.groupby('Dest').size()) / len(df_train)
enc_nom_2
# Out:
# Dest
# ABQ    0.007610
# ALB    0.002813
# AMA    0.001254
# ATL    0.029814
# AUS    0.017643
#          ...
# SYR    0.000032
# TPA    0.020701
# TUL    0.003361
# TUS    0.002991
# VPS    0.000308
# Length: 109, dtype: float64

# %%
df_train['Dest_enc'] = df_train['Dest'].apply(lambda x : enc_nom_2[x])
df_train.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 1  2018-01-09    LAS  OAK         925   1029.0             64.0      64.0
# 2  2018-01-09    LAS  OAK        1820   1826.0              6.0       6.0
# 4  2018-01-09    LAS  OAK        2155   2317.0             82.0      82.0
# 6  2018-01-09    LAS  OAK        1145   1436.0            171.0     171.0
# 8  2018-01-09    LAS  OAK         615    610.0              0.0      -5.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  TaxiIn  CRSArrTime  ArrDelay  \
# 1   1154.0             54.0     64.0  ...     5.0        1100      54.0
# 2   1949.0              0.0     67.0  ...     4.0        1955      -6.0
# 4     41.0             76.0     71.0  ...     5.0        2325      76.0
# 6   1607.0            167.0     64.0  ...     5.0        1320     167.0
# 8    733.0              0.0     62.0  ...     6.0         750     -17.0
#
#    ArrDel15  ArrivalDelayGroups  ArrTimeBlk  DistanceGroup  \
# ...

# %%
df_train = df_train.drop('Origin',axis = 1)
df_train = df_train.drop('Dest',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 1  2018-01-09         925   1029.0             64.0      64.0   1154.0
# 2  2018-01-09        1820   1826.0              6.0       6.0   1949.0
# 4  2018-01-09        2155   2317.0             82.0      82.0     41.0
# 6  2018-01-09        1145   1436.0            171.0     171.0   1607.0
# 8  2018-01-09         615    610.0              0.0      -5.0    733.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  TaxiIn  \
# 1             54.0     64.0            95.0               85.0  ...     5.0
# 2              0.0     67.0            95.0               83.0  ...     4.0
# 4             76.0     71.0            90.0               84.0  ...     5.0
# 6            167.0     64.0            95.0               91.0  ...     5.0
# 8              0.0     62.0            95.0               83.0  ...     6.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# ...

# %%
df_train = df_train.drop('DivAirportLandings',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 1  2018-01-09         925   1029.0             64.0      64.0   1154.0
# 2  2018-01-09        1820   1826.0              6.0       6.0   1949.0
# 4  2018-01-09        2155   2317.0             82.0      82.0     41.0
# 6  2018-01-09        1145   1436.0            171.0     171.0   1607.0
# 8  2018-01-09         615    610.0              0.0      -5.0    733.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  WheelsOn  \
# 1             54.0     64.0            95.0               85.0  ...    1149.0
# 2              0.0     67.0            95.0               83.0  ...    1945.0
# 4             76.0     71.0            90.0               84.0  ...      36.0
# 6            167.0     64.0            95.0               91.0  ...    1602.0
# 8              0.0     62.0            95.0               83.0  ...     727.0
#
# ...

# %%
df_train = df_train.drop('DistanceGroup',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 1  2018-01-09         925   1029.0             64.0      64.0   1154.0
# 2  2018-01-09        1820   1826.0              6.0       6.0   1949.0
# 4  2018-01-09        2155   2317.0             82.0      82.0     41.0
# 6  2018-01-09        1145   1436.0            171.0     171.0   1607.0
# 8  2018-01-09         615    610.0              0.0      -5.0    733.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  \
# 1             54.0     64.0            95.0               85.0  ...
# 2              0.0     67.0            95.0               83.0  ...
# 4             76.0     71.0            90.0               84.0  ...
# 6            167.0     64.0            95.0               91.0  ...
# 8              0.0     62.0            95.0               83.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
df_train = df_train.drop('ArrDelay',axis = 1)
df_train = df_train.drop('DepDelay',axis = 1)
df_train = df_train.drop('ArrDel15',axis = 1)
df_train = df_train.drop('ArrivalDelayGroups',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  \
# 1     64.0            95.0               85.0     407.0  ...
# 2     67.0            95.0               83.0     407.0  ...
# 4     71.0            90.0               84.0     407.0  ...
# 6     64.0            95.0               91.0     407.0  ...
# 8     62.0            95.0               83.0     407.0  ...
#
#    DepartureDelayGroups  DepTimeBlk  TaxiOut  WheelsOff  WheelsOn TaxiIn  \
# ...

# %%
df_train = df_train.drop('ArrTimeBlk',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DepDel15  \
# 1     64.0            95.0               85.0     407.0  ...       1.0
# 2     67.0            95.0               83.0     407.0  ...       0.0
# 4     71.0            90.0               84.0     407.0  ...       1.0
# 6     64.0            95.0               91.0     407.0  ...       1.0
# 8     62.0            95.0               83.0     407.0  ...       0.0
#
# ...

# %%
df_train = df_train.drop('DepTimeBlk',axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DestWac  \
# 1     64.0            95.0               85.0     407.0  ...       91
# 2     67.0            95.0               83.0     407.0  ...       91
# 4     71.0            90.0               84.0     407.0  ...       91
# 6     64.0            95.0               91.0     407.0  ...       91
# 8     62.0            95.0               83.0     407.0  ...       91
#
#    DepDel15  DepartureDelayGroups  TaxiOut  WheelsOff WheelsOn TaxiIn  \
# ...

# %%
df_train= df_train.drop(['Flight_Number_Marketing_Airline', 'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline', 'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName', 'OriginState','OriginStateFips', 'OriginStateName', 'OriginWac', 'DestAirportID','DestAirportSeqID','DestCityMarketID', 'DestCityName', 'DestState', 'DestStateFips', 'DestStateName', 'DestWac'], axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  \
# 1     64.0            95.0               85.0     407.0  ...
# 2     67.0            95.0               83.0     407.0  ...
# 4     71.0            90.0               84.0     407.0  ...
# 6     64.0            95.0               91.0     407.0  ...
# 8     62.0            95.0               83.0     407.0  ...
#
#    Operating_Airline  DepDel15  DepartureDelayGroups  TaxiOut  WheelsOff  \
# ...

# %%
df_train= df_train.drop(['DepDel15', 'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners', 'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline'], axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DayOfWeek  \
# 1     64.0            95.0               85.0     407.0  ...          2
# 2     67.0            95.0               83.0     407.0  ...          2
# 4     71.0            90.0               84.0     407.0  ...          2
# 6     64.0            95.0               91.0     407.0  ...          2
# 8     62.0            95.0               83.0     407.0  ...          2
#
# ...

# %%
df_train= df_train.drop('Year', axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DayOfWeek  \
# 1     64.0            95.0               85.0     407.0  ...          2
# 2     67.0            95.0               83.0     407.0  ...          2
# 4     71.0            90.0               84.0     407.0  ...          2
# 6     64.0            95.0               91.0     407.0  ...          2
# 8     62.0            95.0               83.0     407.0  ...          2
#
# ...

# %%
df_train= df_train.drop(['WheelsOn', 'WheelsOff'], axis = 1)
df_train.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 1  2018-01-09         925   1029.0             64.0   1154.0             54.0
# 2  2018-01-09        1820   1826.0              6.0   1949.0              0.0
# 4  2018-01-09        2155   2317.0             82.0     41.0             76.0
# 6  2018-01-09        1145   1436.0            171.0   1607.0            167.0
# 8  2018-01-09         615    610.0              0.0    733.0              0.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  Month  \
# 1     64.0            95.0               85.0     407.0  ...      1
# 2     67.0            95.0               83.0     407.0  ...      1
# 4     71.0            90.0               84.0     407.0  ...      1
# 6     64.0            95.0               91.0     407.0  ...      1
# 8     62.0            95.0               83.0     407.0  ...      1
#
#    DayofMonth  DayOfWeek  Operating_Airline DepartureDelayGroups  TaxiOut  \
# ...

# %%
df_train = df_train.drop(['Operating_Airline', 'AirTime', 'CRSElapsedTime','ActualElapsedTime'], axis = 1)

# %%
df_train= df_train.drop(['DepartureDelayGroups'], axis = 1)

# %%
import plotly.express as px

corrmat = df_train.corr() 
fig = px.imshow(corrmat,
                labels = dict(color='Correlation'),
                x=corrmat.columns,
                y=corrmat.index,
                color_continuous_scale='Viridis',
                title='Correlation Matrix')
fig.update_layout(width=800, height=800)
fig.show()
# Out:
# /var/folders/z1/0b4fr5_n0fg0z6szcfq9km100000gn/T/ipykernel_3851/3219507541.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# #### Testing Set

# %%
df_test = pd.read_csv("/Users/bristi/Desktop/Preprocessing/southwest_test.csv")

# %%
df_notcancelled = df_test[df_test["Cancelled"] == False]

# %%
df_notcancelled = df_notcancelled.drop('Cancelled', axis = 1)

# %%
df_test = df_notcancelled[df_notcancelled["Diverted"] == False]
df_test = df_test.drop('Diverted', axis = 1)

# %%
null_dep_time_count = df_test["DepTime"].isnull().sum()
print("Number of records with null DepTime:", null_dep_time_count)
# Out:
# Number of records with null DepTime: 0

# %%
df_test = df_test.drop("Airline", axis=1)

# %%
df_test.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  2022-04-01    ABQ  AUS        1035   1037.0              2.0       2.0
# 1  2022-04-01    ABQ  BUR        1750   1823.0             33.0      33.0
# 2  2022-04-01    ABQ  DAL         645    648.0              3.0       3.0
# 3  2022-04-01    ABQ  DAL        1150   1146.0              0.0      -4.0
# 4  2022-04-01    ABQ  DAL        1730   1757.0             27.0      27.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  WheelsOff  WheelsOn  TaxiIn  \
# 0   1303.0              0.0     75.0  ...     1045.0    1300.0     3.0
# 1   1914.0             24.0     96.0  ...     1836.0    1912.0     2.0
# 2    922.0              0.0     79.0  ...      701.0     920.0     2.0
# 3   1439.0              4.0     76.0  ...     1155.0    1411.0    28.0
# 4   2042.0             32.0     83.0  ...     1810.0    2033.0     9.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# ...

# %%
enc_nom_1 = (df_test.groupby('Origin').size()) / len(df_test)
enc_nom_1
# Out:
# Origin
# ABQ    0.006088
# ALB    0.002102
# AMA    0.001470
# ATL    0.024459
# AUS    0.026402
#          ...
# SYR    0.000880
# TPA    0.017799
# TUL    0.003281
# TUS    0.002644
# VPS    0.001373
# Length: 107, dtype: float64

# %%
df_test['Origin_enc'] = df_test['Origin'].apply(lambda x : enc_nom_1[x])
df_test.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  2022-04-01    ABQ  AUS        1035   1037.0              2.0       2.0
# 1  2022-04-01    ABQ  BUR        1750   1823.0             33.0      33.0
# 2  2022-04-01    ABQ  DAL         645    648.0              3.0       3.0
# 3  2022-04-01    ABQ  DAL        1150   1146.0              0.0      -4.0
# 4  2022-04-01    ABQ  DAL        1730   1757.0             27.0      27.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  WheelsOn  TaxiIn  CRSArrTime  \
# 0   1303.0              0.0     75.0  ...    1300.0     3.0        1315
# 1   1914.0             24.0     96.0  ...    1912.0     2.0        1850
# 2    922.0              0.0     79.0  ...     920.0     2.0         930
# 3   1439.0              4.0     76.0  ...    1411.0    28.0        1435
# 4   2042.0             32.0     83.0  ...    2033.0     9.0        2010
#
#    ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  DistanceGroup  \
# ...

# %%
enc_nom_2 = (df_test.groupby('Dest').size()) / len(df_test)
enc_nom_2
# Out:
# Dest
# ABQ    0.006102
# ALB    0.002120
# AMA    0.001478
# ATL    0.024404
# AUS    0.026439
#          ...
# SYR    0.000889
# TPA    0.017742
# TUL    0.003302
# TUS    0.002644
# VPS    0.001375
# Length: 107, dtype: float64

# %%
df_test['Dest_enc'] = df_test['Dest'].apply(lambda x : enc_nom_2[x])
df_test.head()
# Out:
#    FlightDate Origin Dest  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0  2022-04-01    ABQ  AUS        1035   1037.0              2.0       2.0
# 1  2022-04-01    ABQ  BUR        1750   1823.0             33.0      33.0
# 2  2022-04-01    ABQ  DAL         645    648.0              3.0       3.0
# 3  2022-04-01    ABQ  DAL        1150   1146.0              0.0      -4.0
# 4  2022-04-01    ABQ  DAL        1730   1757.0             27.0      27.0
#
#    ArrTime  ArrDelayMinutes  AirTime  ...  TaxiIn  CRSArrTime  ArrDelay  \
# 0   1303.0              0.0     75.0  ...     3.0        1315     -12.0
# 1   1914.0             24.0     96.0  ...     2.0        1850      24.0
# 2    922.0              0.0     79.0  ...     2.0         930      -8.0
# 3   1439.0              4.0     76.0  ...    28.0        1435       4.0
# 4   2042.0             32.0     83.0  ...     9.0        2010      32.0
#
#    ArrDel15  ArrivalDelayGroups  ArrTimeBlk  DistanceGroup  \
# ...

# %%
df_test = df_test.drop('Origin',axis = 1)
df_test = df_test.drop('Dest',axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 0  2022-04-01        1035   1037.0              2.0       2.0   1303.0
# 1  2022-04-01        1750   1823.0             33.0      33.0   1914.0
# 2  2022-04-01         645    648.0              3.0       3.0    922.0
# 3  2022-04-01        1150   1146.0              0.0      -4.0   1439.0
# 4  2022-04-01        1730   1757.0             27.0      27.0   2042.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  TaxiIn  \
# 0              0.0     75.0           100.0               86.0  ...     3.0
# 1             24.0     96.0           120.0              111.0  ...     2.0
# 2              0.0     79.0           105.0               94.0  ...     2.0
# 3              4.0     76.0           105.0              113.0  ...    28.0
# 4             32.0     83.0           100.0              105.0  ...     9.0
#
#    CRSArrTime  ArrDelay  ArrDel15  ArrivalDelayGroups  ArrTimeBlk  \
# ...

# %%
df_test = df_test.drop('DivAirportLandings',axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 0  2022-04-01        1035   1037.0              2.0       2.0   1303.0
# 1  2022-04-01        1750   1823.0             33.0      33.0   1914.0
# 2  2022-04-01         645    648.0              3.0       3.0    922.0
# 3  2022-04-01        1150   1146.0              0.0      -4.0   1439.0
# 4  2022-04-01        1730   1757.0             27.0      27.0   2042.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  WheelsOn  \
# 0              0.0     75.0           100.0               86.0  ...    1300.0
# 1             24.0     96.0           120.0              111.0  ...    1912.0
# 2              0.0     79.0           105.0               94.0  ...     920.0
# 3              4.0     76.0           105.0              113.0  ...    1411.0
# 4             32.0     83.0           100.0              105.0  ...    2033.0
#
# ...

# %%
df_test = df_test.drop('DistanceGroup',axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 0  2022-04-01        1035   1037.0              2.0       2.0   1303.0
# 1  2022-04-01        1750   1823.0             33.0      33.0   1914.0
# 2  2022-04-01         645    648.0              3.0       3.0    922.0
# 3  2022-04-01        1150   1146.0              0.0      -4.0   1439.0
# 4  2022-04-01        1730   1757.0             27.0      27.0   2042.0
#
#    ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  ...  \
# 0              0.0     75.0           100.0               86.0  ...
# 1             24.0     96.0           120.0              111.0  ...
# 2              0.0     79.0           105.0               94.0  ...
# 3              4.0     76.0           105.0              113.0  ...
# 4             32.0     83.0           100.0              105.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
df_test = df_test.drop('DepDelay',axis = 1)
df_test = df_test.drop('ArrDelay',axis = 1)
df_test = df_test.drop('ArrDel15',axis = 1)
df_test = df_test.drop('ArrivalDelayGroups',axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  \
# 0     75.0           100.0               86.0     619.0  ...
# 1     96.0           120.0              111.0     672.0  ...
# 2     79.0           105.0               94.0     580.0  ...
# 3     76.0           105.0              113.0     580.0  ...
# 4     83.0           100.0              105.0     580.0  ...
#
#    DepartureDelayGroups  DepTimeBlk  TaxiOut  WheelsOff  WheelsOn TaxiIn  \
# ...

# %%
df_test = df_test.drop('ArrTimeBlk', axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DepDel15  \
# 0     75.0           100.0               86.0     619.0  ...       0.0
# 1     96.0           120.0              111.0     672.0  ...       1.0
# 2     79.0           105.0               94.0     580.0  ...       0.0
# 3     76.0           105.0              113.0     580.0  ...       0.0
# 4     83.0           100.0              105.0     580.0  ...       1.0
#
# ...

# %%
df_test = df_test.drop('DepTimeBlk',axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DestWac  \
# 0     75.0           100.0               86.0     619.0  ...       74
# 1     96.0           120.0              111.0     672.0  ...       91
# 2     79.0           105.0               94.0     580.0  ...       74
# 3     76.0           105.0              113.0     580.0  ...       74
# 4     83.0           100.0              105.0     580.0  ...       74
#
#    DepDel15  DepartureDelayGroups  TaxiOut  WheelsOff WheelsOn TaxiIn  \
# ...

# %%
df_test= df_test.drop(['Flight_Number_Marketing_Airline', 'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline', 'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName', 'OriginState','OriginStateFips', 'OriginStateName', 'OriginWac', 'DestAirportID','DestAirportSeqID','DestCityMarketID', 'DestCityName', 'DestState', 'DestStateFips', 'DestStateName', 'DestWac'], axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  \
# 0     75.0           100.0               86.0     619.0  ...
# 1     96.0           120.0              111.0     672.0  ...
# 2     79.0           105.0               94.0     580.0  ...
# 3     76.0           105.0              113.0     580.0  ...
# 4     83.0           100.0              105.0     580.0  ...
#
#    Operating_Airline  DepDel15  DepartureDelayGroups  TaxiOut  WheelsOff  \
# ...

# %%
df_test= df_test.drop(['DepDel15', 'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners', 'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline'], axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DayOfWeek  \
# 0     75.0           100.0               86.0     619.0  ...          5
# 1     96.0           120.0              111.0     672.0  ...          5
# 2     79.0           105.0               94.0     580.0  ...          5
# 3     76.0           105.0              113.0     580.0  ...          5
# 4     83.0           100.0              105.0     580.0  ...          5
#
# ...

# %%
df_test= df_test.drop('Year', axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  DayOfWeek  \
# 0     75.0           100.0               86.0     619.0  ...          5
# 1     96.0           120.0              111.0     672.0  ...          5
# 2     79.0           105.0               94.0     580.0  ...          5
# 3     76.0           105.0              113.0     580.0  ...          5
# 4     83.0           100.0              105.0     580.0  ...          5
#
# ...

# %%
df_test= df_test.drop(['WheelsOn', 'WheelsOff'], axis = 1)
df_test.head()
# Out:
#    FlightDate  CRSDepTime  DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  \
# 0  2022-04-01        1035   1037.0              2.0   1303.0              0.0
# 1  2022-04-01        1750   1823.0             33.0   1914.0             24.0
# 2  2022-04-01         645    648.0              3.0    922.0              0.0
# 3  2022-04-01        1150   1146.0              0.0   1439.0              4.0
# 4  2022-04-01        1730   1757.0             27.0   2042.0             32.0
#
#    AirTime  CRSElapsedTime  ActualElapsedTime  Distance  ...  Month  \
# 0     75.0           100.0               86.0     619.0  ...      4
# 1     96.0           120.0              111.0     672.0  ...      4
# 2     79.0           105.0               94.0     580.0  ...      4
# 3     76.0           105.0              113.0     580.0  ...      4
# 4     83.0           100.0              105.0     580.0  ...      4
#
#    DayofMonth  DayOfWeek  Operating_Airline DepartureDelayGroups  TaxiOut  \
# ...

# %%
df_test = df_test.drop(['Operating_Airline', 'AirTime', 'CRSElapsedTime','ActualElapsedTime'], axis = 1)
df_test= df_test.drop(['DepartureDelayGroups'], axis = 1)

# %%
df_test.columns
# Out:
# Index(['FlightDate', 'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'ArrTime',
#        'ArrDelayMinutes', 'Distance', 'Quarter', 'Month', 'DayofMonth',
#        'DayOfWeek', 'TaxiOut', 'TaxiIn', 'CRSArrTime', 'Origin_enc',
#        'Dest_enc'],
#       dtype='object')

# %%
import plotly.express as px

corrmat = df_test.corr() 
fig = px.imshow(corrmat,
                labels = dict(color='Correlation'),
                x=corrmat.columns,
                y=corrmat.index,
                color_continuous_scale='Viridis',
                title='Correlation Matrix')
fig.update_layout(width=800, height=800)
fig.show()
# Out:
# /var/folders/z1/0b4fr5_n0fg0z6szcfq9km100000gn/T/ipykernel_3851/532356424.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# #### PCA with Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np

# %%
df_train.shape
# Out:
# (4580345, 16)

# %%
print("PCA")
# for_plotting = df_test['FlightDate']

train_features = df_train.drop(['ArrDelayMinutes','FlightDate'], axis=1)

scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(train_features)

model = PCA(n_components=5).fit(scaled_train_features)
X_pc = model.transform(scaled_train_features)

# Get the number of principal components and feature names
n_pcs = model.components_.shape[0]
initial_feature_names = df_train.drop(['ArrDelayMinutes','FlightDate'], axis=1).columns

# Find the most important feature for each principal component
most_important = [np.abs(model.components_[i]).argmax() for i in range(n_pcs)]
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]
most_important_names = list(set(most_important_names))
most_important_names
# Out:
# PCA
# ['Distance', 'DepDelayMinutes', 'Dest_enc', 'Month', 'DepTime']

# %% [markdown]
# #### Random Forest Feature Selection

# %%
X = df_train.drop(['ArrDelayMinutes', 'FlightDate'], axis=1)
y = df_train['ArrDelayMinutes']

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np

# Assuming 'X' contains your features and 'y' contains the target variable
# X should be a DataFrame containing your features, and y should be a Series containing the target variable

# Initialize Random Forest Regressor
rf = RandomForestRegressor(n_estimators=25, random_state=42)

# Fit the model
rf.fit(X, y)

# Get feature importances
feature_importances = rf.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame(
    {'Feature': X.columns, 'Importance': feature_importances}
)

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(
    by='Importance', ascending=False
)

# Display the top n important features
n = 5  # Change this value to display a different number of top features
top_n_features = feature_importance_df.head(n)
print(f'Top {n} Features:')
print(top_n_features)
# Out:
# Top 5 Features:
#             Feature  Importance
# 2   DepDelayMinutes    0.931820
# 9           TaxiOut    0.024242
# 10           TaxiIn    0.011116
# 3           ArrTime    0.005166
# 4          Distance    0.004947

# %% [markdown]
# #### Model building -  Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# Using PCA feature selection

# %%
X = df_train[['Distance', 'DepDelayMinutes', 'Dest_enc', 'Month', 'DepTime']]
y = df_train[['ArrDelayMinutes']]

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

y_pred = model.predict(X)

# %%
mae = mean_absolute_error(y, y_pred)
print("Mean Absolute Error (MAE):", mae)

mse = mean_squared_error(y, y_pred)
print("Mean Squared Error (MSE):", mse)

r2score = r2_score(y, y_pred)
print("R2 Score:", r2score)
# Out:
# Mean Absolute Error (MAE): 3.878259809081755
# Mean Squared Error (MSE): 56.05132380083712
# R2 Score: 0.9228269584782601

# %%
X_test = df_test[['Distance', 'DepDelayMinutes', 'Dest_enc', 'Month', 'DepTime']]
y_test = df_test[['ArrDelayMinutes']]

# %%
pred = model.predict(X_test)
r2score = r2_score(y_test, pred)
print("R2 Score:", r2score)
# Out:
# R2 Score: 0.919541858153434

# %% [markdown]
# Using Random Forest Feature Selection

# %%
X = df_train[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y = df_train[['ArrDelayMinutes']]

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

y_pred = model.predict(X)

# %%
mae = mean_absolute_error(y, y_pred)
print("Mean Absolute Error (MAE):", mae)

mse = mean_squared_error(y, y_pred)
print("Mean Squared Error (MSE):", mse)

r2score = r2_score(y, y_pred)
print("R2 Score:", r2score)
# Out:
# Mean Absolute Error (MAE): 4.195738616655413
# Mean Squared Error (MSE): 39.27009760759567
# R2 Score: 0.9459318234123759

# %%
X_test = df_test[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y_test = df_test[['ArrDelayMinutes']]

# %%
pred = model.predict(X_test)
r2score = r2_score(y_test, pred)
print("R2 Score:", r2score)
# Out:
# R2 Score: 0.9506730178864575

# %% [markdown]
# #### Grid Search for Hyperparameter Tuning in Random Forest Regression

# %% [markdown]
# Using Random Forest Feature Selection

# %%
X = df_train[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y = df_train[['ArrDelayMinutes']]

# %%
param_grid = {
    'n_estimators': [10, 20, 30],  
    'max_depth': [None, 5, 10, 15], 
    'min_samples_split': [2, 4, 8],  
    "bootstrap": [True, False]
}

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X, y)
# Out:
# /Users/bristi/miniforge3/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/bristi/miniforge3/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Users/bristi/miniforge3/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'bootstrap': True, 'max_depth': 15, 'min_samples_split': 8, 'n_estimators': 30}

# %%
best_rf = grid_search.best_estimator_
best_rf.fit(X, y)

# Assess the model on the test set
mse = mean_squared_error(y_test, best_rf.predict(X_test))
print("Mean Squared Error on Test Set:", mse)
# Out:
# /Users/bristi/miniforge3/lib/python3.9/site-packages/sklearn/base.py:1152: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Mean Squared Error on Test Set: 31.592643541255942

# %%
X_test = df_test[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y_test = df_test[['ArrDelayMinutes']]

# %%
pred = best_rf.predict(X_test)
r2score = r2_score(y_test, pred)
print("R2 Score:", r2score)
# Out:
# R2 Score: 0.9676044506338946

# %% [markdown]
# #### Model building -  XGB regression model

# %%
import xgboost as xg

# %% [markdown]
# Using PCA feature selection

# %%
X = df_train[['Distance', 'DepDelayMinutes', 'Dest_enc', 'Month', 'DepTime']]
y = df_train[['ArrDelayMinutes']]

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123) 
  
# Fitting the model 
xgb_r.fit(X, y) 

y_pred = xgb_r.predict(X)
# Out:
# /Users/bristi/miniforge3/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning:
#
# [20:50:55] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.

# %%
mae = mean_absolute_error(y, y_pred)
print("Mean Absolute Error (MAE):", mae)

mse = mean_squared_error(y, y_pred)
print("Mean Squared Error (MSE):", mse)

r2score = r2_score(y, y_pred)
print("R2 Score:", r2score)
# Out:
# Mean Absolute Error (MAE): 3.6834802613412996
# Mean Squared Error (MSE): 56.22330723146696
# R2 Score: 0.9225901668463584

# %%
X_test = df_test[['Distance', 'DepDelayMinutes', 'Dest_enc', 'Month', 'DepTime']]
y_test = df_test[['ArrDelayMinutes']]

# %%
pred = xgb_r.predict(X_test)
r2score = r2_score(y_test, pred)
print("R2 Score:", r2score)
# Out:
# R2 Score: 0.917312592589079

# %% [markdown]
# Using Random Forest Feature Selection

# %%
X = df_train[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y = df_train[['ArrDelayMinutes']]

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123) 
  
# Fitting the model 
xgb_r.fit(X, y) 

y_pred = xgb_r.predict(X)
# Out:
# /Users/bristi/miniforge3/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning:
#
# [20:51:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.

# %%
mae = mean_absolute_error(y, y_pred)
print("Mean Absolute Error (MAE):", mae)

mse = mean_squared_error(y, y_pred)
print("Mean Squared Error (MSE):", mse)

r2score = r2_score(y, y_pred)
print("R2 Score:", r2score)
# Out:
# Mean Absolute Error (MAE): 2.8398514808790405
# Mean Squared Error (MSE): 33.53386336208978
# R2 Score: 0.9538296323058786

# %%
X_test = df_test[['DepDelayMinutes', 'TaxiOut', 'TaxiIn', 'ArrTime', 'Distance']]
y_test = df_test[['ArrDelayMinutes']]

# %%
pred = xgb_r.predict(X_test)
r2score = r2_score(y_test, pred)
print("R2 Score:", r2score)
# Out:
# R2 Score: 0.9564732943656136

# %% [markdown]
# #### Visualization

# %%
pred = pd.DataFrame(pred)

# %%
#Merged actual flight date and arrival delay minutes

actual = pd.concat([ df_test[['FlightDate']].reset_index(drop=True), y_test.reset_index(drop=True)], axis=1)
actual
# Out:
#         FlightDate  ArrDelayMinutes
# 0       2022-04-01              0.0
# 1       2022-04-01             24.0
# 2       2022-04-01              0.0
# 3       2022-04-01              4.0
# 4       2022-04-01             32.0
# ...            ...              ...
# 712241  2022-03-28              0.0
# 712242  2022-03-28              3.0
# 712243  2022-03-28             68.0
# 712244  2022-03-28              0.0
# 712245  2022-03-28              0.0
#
# [712246 rows x 2 columns]

# %%
#Merged predicted flight date and arrival delay minutes

predicted = pd.concat([ df_test[['FlightDate']].reset_index(drop=True), pred.reset_index(drop=True)], axis=1)
predicted
# Out:
#         FlightDate          0
# 0       2022-04-01   0.650093
# 1       2022-04-01  24.159515
# 2       2022-04-01   1.789417
# 3       2022-04-01   9.334227
# 4       2022-04-01  22.255114
# ...            ...        ...
# 712241  2022-03-28   1.139779
# 712242  2022-03-28  14.345838
# 712243  2022-03-28  66.731949
# 712244  2022-03-28   1.808762
# 712245  2022-03-28   0.872056
#
# [712246 rows x 2 columns]

# %%
# Average predicted delay of flights on a single day

df5 = predicted

average_values = df5.groupby('FlightDate')[0].mean().reset_index()
average_values.rename(columns={0: 'Average_ArrivalDelay'}, inplace=True)
merged_df = pd.merge(df5, average_values, on='FlightDate', how='left')
final_predicted = merged_df.drop_duplicates(subset='FlightDate')
final_predicted = final_predicted.drop([0], axis=1)
final_predicted = final_predicted.sort_values(by='FlightDate', ascending=True)
final_predicted
# Out:
#         FlightDate  Average_ArrivalDelay
# 519907  2022-01-01             24.627625
# 522813  2022-01-02             41.744385
# 525913  2022-01-03             39.971672
# 549530  2022-01-04             35.563423
# 552026  2022-01-05             29.129509
# ...            ...                   ...
# 210353  2022-07-27             21.581018
# 214140  2022-07-28             16.659296
# 270289  2022-07-29             17.246696
# 274126  2022-07-30             11.446174
# 277451  2022-07-31             17.243233
#
# [212 rows x 2 columns]

# %%
# Average actual delay of flights on a single day

df6 = actual

average_values = df6.groupby('FlightDate')['ArrDelayMinutes'].mean().reset_index()
average_values.rename(columns={'ArrDelayMinutes': 'Average_ArrivalDelay'}, inplace=True)
merged_df = pd.merge(df6, average_values, on='FlightDate', how='left')
final_actual = merged_df.drop_duplicates(subset='FlightDate')
final_actual = final_actual.drop(['ArrDelayMinutes'], axis=1)
final_actual = final_actual.sort_values(by='FlightDate', ascending=True)
final_actual
# Out:
#         FlightDate  Average_ArrivalDelay
# 519907  2022-01-01             25.235375
# 522813  2022-01-02             42.722258
# 525913  2022-01-03             40.204593
# 549530  2022-01-04             35.560897
# 552026  2022-01-05             29.068632
# ...            ...                   ...
# 210353  2022-07-27             22.383875
# 214140  2022-07-28             17.397647
# 270289  2022-07-29             17.974987
# 274126  2022-07-30             11.418647
# 277451  2022-07-31             17.528257
#
# [212 rows x 2 columns]

# %%
start_date = '2022-08-01'
end_date = '2022-12-31'

missing_dates = pd.date_range(start=start_date, end=end_date, freq='D')
missing_data = pd.DataFrame({
    'FlightDate': missing_dates,
    'Average_ArrivalDelay': -1
})

final_actual['FlightDate'] = pd.to_datetime(final_actual['FlightDate'])
missing_data['FlightDate'] = pd.to_datetime(missing_data['FlightDate'])


final_actual = pd.concat([final_actual, missing_data])

final_actual = final_actual.sort_values('FlightDate').reset_index(drop=True)
final_actual
# Out:
#     FlightDate  Average_ArrivalDelay
# 0   2022-01-01             25.235375
# 1   2022-01-02             42.722258
# 2   2022-01-03             40.204593
# 3   2022-01-04             35.560897
# 4   2022-01-05             29.068632
# ..         ...                   ...
# 360 2022-12-27             -1.000000
# 361 2022-12-28             -1.000000
# 362 2022-12-29             -1.000000
# 363 2022-12-30             -1.000000
# 364 2022-12-31             -1.000000
#
# [365 rows x 2 columns]

# %%
import plotly.io as pio
from plotly_calplot import calplot
from plotly.offline import plot

fig = calplot(
    final_actual, 
    x= "FlightDate", 
    y = "Average_ArrivalDelay",
    dark_theme=False,
    years_title=True,
    gap=1,
    name="ArrDelayMinutes",
    month_lines_width=2, 
    month_lines_color="black",
    colorscale="magma",
    showscale=True,
    cmap_max=69,
    cmap_min= 0
    )

final_actual['FlightDate'] = pd.to_datetime(final_actual['FlightDate'])
date_formatted = final_actual['FlightDate'].dt.strftime('%Y-%m-%d')

fig.update_layout(title_text=f'<b>Actual Average ArrivalDelay for flights</b>')
fig.update_layout(width=800)


pio.show(fig)

# %%
final_predicted['FlightDate'] = pd.to_datetime(final_predicted['FlightDate'])
missing_data['FlightDate'] = pd.to_datetime(missing_data['FlightDate'])

final_predicted = pd.concat([final_predicted, missing_data])

final_predicted = final_predicted.sort_values('FlightDate').reset_index(drop=True)
final_predicted
# Out:
#     FlightDate  Average_ArrivalDelay
# 0   2022-01-01             24.627625
# 1   2022-01-02             41.744385
# 2   2022-01-03             39.971672
# 3   2022-01-04             35.563423
# 4   2022-01-05             29.129509
# ..         ...                   ...
# 360 2022-12-27             -1.000000
# 361 2022-12-28             -1.000000
# 362 2022-12-29             -1.000000
# 363 2022-12-30             -1.000000
# 364 2022-12-31             -1.000000
#
# [365 rows x 2 columns]

# %%
fig = calplot(
    final_predicted, 
    x= "FlightDate", 
    y = "Average_ArrivalDelay",
    dark_theme=False,
    years_title=True,
    gap=1,
    name="ArrDelayMinutes",
    month_lines_width=2, 
    month_lines_color="black",
    colorscale="magma",
    showscale=True,
    cmap_max=69,
    cmap_min= 0
    )

final_predicted['FlightDate'] = pd.to_datetime(final_predicted['FlightDate'])
date_formatted = final_predicted['FlightDate'].dt.strftime('%Y-%m-%d')

fig.update_layout(title_text=f'<b>Predicted Average ArrivalDelay for flights</b>')
fig.update_layout(width=800)

pio.show(fig)

# %%
final_diff = final_predicted
final_diff['Average_ArrivalDelay'] = final_predicted['Average_ArrivalDelay'] - final_actual['Average_ArrivalDelay']

fig = calplot(
    final_diff, 
    x= "FlightDate", 
    y = "Average_ArrivalDelay",
    dark_theme=False,
    years_title=True,
    gap=1,
    name="ArrDelayMinutes",
    month_lines_width=2, 
    month_lines_color="black",
    colorscale="magma",
    showscale=True
    # cmap_max= 2,
    # cmap_min= -60
    )

final_diff['FlightDate'] = pd.to_datetime(final_diff['FlightDate'])
date_formatted = final_diff['FlightDate'].dt.strftime('%Y-%m-%d')

fig.update_layout(title_text=f'<b>Delta Average ArrivalDelay for flights</b>')
fig.update_layout(width=800)

pio.show(fig)

# %%
import plotly.express as px


fig = px.scatter(final_diff, x='FlightDate', y='Average_ArrivalDelay', title='Arrival Delay vs Flight Date')
fig.update_layout(xaxis_title='Flight Date', yaxis_title='Average Arrival Delay')

fig.show()
